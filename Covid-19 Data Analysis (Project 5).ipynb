# %% [markdown]
# # Working on Real Project with Python on 'COVID-19 dataset'

# %% [markdown]
# # (A Part of Big Data Analysis)

# %% [markdown]
# # COVID-19 SMALL DATASET

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Read the csv file from the Dataset Covid-19.

# %%
 data = pd.read_csv('4. covid_19_data.csv')

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %% [markdown]
# # .count()

# %%
data.count()
#null values means Missing values
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %% [markdown]
# # .isnull()

# %%
data.isnull()
# Out:
#       Date  State  Region  Confirmed  Deaths  Recovered
# 0    False   True   False      False   False      False
# 1    False   True   False      False   False      False
# 2    False   True   False      False   False      False
# 3    False   True   False      False   False      False
# 4    False   True   False      False   False      False
# ..     ...    ...     ...        ...     ...        ...
# 316  False  False   False      False   False      False
# 317  False  False   False      False   False      False
# 318  False  False   False      False   False      False
# 319  False  False   False      False   False      False
# 320  False  False   False      False   False      False
#
# [321 rows x 6 columns]

# %% [markdown]
# # .isnull().sum()

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
 sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# # Q 1.) Show the number of Confirmed, Deaths and Recovered cases in each Region.

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby('Region').sum()
# Out:
# C:\Users\Akshit Koche\AppData\Local\Temp\ipykernel_15156\1381090450.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('Region').sum()
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %%
data.groupby('Region').sum().head(20)
# Out:
# C:\Users\Akshit Koche\AppData\Local\Temp\ipykernel_15156\3787432426.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('Region').sum().head(20)
#                      Confirmed  Deaths  Recovered
# Region
# Afghanistan               1939      60        252
# Albania                    766      30        455
# Algeria                   3848     444       1702
# Andorra                    743      42        423
# Angola                      27       2          7
# Antigua and Barbuda         24       3         11
# Argentina                 4285     214       1192
# Armenia                   1932      30        900
# Australia                 6752      91       5715
# Austria                  15402     580      12779
# Azerbaijan                1766      23       1267
# ...

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending = False).head(10)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Name: Confirmed, dtype: int64

# %%
data.groupby('Region')['Confirmed'].sum()
# Out:
# Region
# Afghanistan           1939
# Albania                766
# Algeria               3848
# Andorra                743
# Angola                  27
#                       ...
# West Bank and Gaza     344
# Western Sahara           6
# Yemen                    6
# Zambia                  97
# Zimbabwe                32
# Name: Confirmed, Length: 187, dtype: int64

# %% [markdown]
# # Q2) Remove all the Records where Confirmed Cases is Less Than 10.

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data = data[data.Confirmed <10 ]

# %%
data
# Out:
#           Date                             State                 Region  \
# 18   4/29/2020                               NaN                 Bhutan
# 98   4/29/2020                               NaN             MS Zaandam
# 105  4/29/2020                               NaN             Mauritania
# 126  4/29/2020                               NaN       Papua New Guinea
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 177  4/29/2020                               NaN         Western Sahara
# 178  4/29/2020                               NaN                  Yemen
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 194  4/29/2020            British Virgin Islands                     UK
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 272  4/29/2020             Northwest Territories                 Canada
# ...

# %%
data.groupby('Region').sum().head(20)
# Out:
# C:\Users\Akshit Koche\AppData\Local\Temp\ipykernel_15156\3787432426.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('Region').sum().head(20)
#                        Confirmed  Deaths  Recovered
# Region
# Bhutan                         7       0          5
# Canada                         5       1      20327
# France                         7       0          6
# MS Zaandam                     9       2          0
# Mainland China                 1       0          1
# Mauritania                     8       1          6
# Netherlands                    5       0          0
# Papua New Guinea               8       0          0
# Sao Tome and Principe          8       0          4
# UK                             9       1          6
# ...

# %% [markdown]
# # Q 3).InWhich Region,maximum number of Confirmed caes were recorded ?

# %%
data.head()
# Out:
#           Date State                 Region  Confirmed  Deaths  Recovered
# 18   4/29/2020   NaN                 Bhutan          7       0          5
# 98   4/29/2020   NaN             MS Zaandam          9       2          0
# 105  4/29/2020   NaN             Mauritania          8       1          6
# 126  4/29/2020   NaN       Papua New Guinea          8       0          0
# 140  4/29/2020   NaN  Sao Tome and Principe          8       0          4

# %%
data.groupby('Region')['Confirmed'].sum()
# Out:
# Region
# Bhutan                   7
# Canada                   5
# France                   7
# MS Zaandam               9
# Mainland China           1
# Mauritania               8
# Netherlands              5
# Papua New Guinea         8
# Sao Tome and Principe    8
# UK                       9
# US                       0
# Western Sahara           6
# Yemen                    6
# Name: Confirmed, dtype: int64

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending=False)
# Out:
# Region
# MS Zaandam               9
# UK                       9
# Mauritania               8
# Papua New Guinea         8
# Sao Tome and Principe    8
# Bhutan                   7
# France                   7
# Western Sahara           6
# Yemen                    6
# Canada                   5
# Netherlands              5
# Mainland China           1
# US                       0
# Name: Confirmed, dtype: int64

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending=False).head(10)
# Out:
# Region
# MS Zaandam               9
# UK                       9
# Mauritania               8
# Papua New Guinea         8
# Sao Tome and Principe    8
# Bhutan                   7
# France                   7
# Western Sahara           6
# Yemen                    6
# Canada                   5
# Name: Confirmed, dtype: int64

# %% [markdown]
# # Q4). In Which Region ,minimum number of Deaths caes were recorded ?

# %%
data.head(2)
# Out:
#          Date State      Region  Confirmed  Deaths  Recovered
# 18  4/29/2020   NaN      Bhutan          7       0          5
# 98  4/29/2020   NaN  MS Zaandam          9       2          0

# %%
 data.groupby('Region')['Confirmed', 'Recovered'].sum()
# Out:
# C:\Users\Akshit Koche\AppData\Local\Temp\ipykernel_15156\4149335059.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Region')['Confirmed', 'Recovered'].sum()
#                        Confirmed  Recovered
# Region
# Bhutan                         7          5
# Canada                         5      20327
# France                         7          6
# MS Zaandam                     9          0
# Mainland China                 1          1
# Mauritania                     8          6
# Netherlands                    5          0
# Papua New Guinea               8          0
# Sao Tome and Principe          8          4
# UK                             9          6
# US                             0     120720
# Western Sahara                 6          5
# Yemen                          6          1

# %% [markdown]
# # Q 2) Remove all the records where Confirmed Caes is Less Than 10.

# %%
data.head(2)
# Out:
#          Date State      Region  Confirmed  Deaths  Recovered
# 18  4/29/2020   NaN      Bhutan          7       0          5
# 98  4/29/2020   NaN  MS Zaandam          9       2          0

# %%
data = data[data.Confirmed <10 ] # To remove the Records satisfying a particular condition

# %%
data
# Out:
#           Date                             State                 Region  \
# 18   4/29/2020                               NaN                 Bhutan
# 98   4/29/2020                               NaN             MS Zaandam
# 105  4/29/2020                               NaN             Mauritania
# 126  4/29/2020                               NaN       Papua New Guinea
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 177  4/29/2020                               NaN         Western Sahara
# 178  4/29/2020                               NaN                  Yemen
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 194  4/29/2020            British Virgin Islands                     UK
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 272  4/29/2020             Northwest Territories                 Canada
# ...

# %%
data.head(20)
# Out:
#           Date                             State                 Region  \
# 18   4/29/2020                               NaN                 Bhutan
# 98   4/29/2020                               NaN             MS Zaandam
# 105  4/29/2020                               NaN             Mauritania
# 126  4/29/2020                               NaN       Papua New Guinea
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 177  4/29/2020                               NaN         Western Sahara
# 178  4/29/2020                               NaN                  Yemen
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 194  4/29/2020            British Virgin Islands                     UK
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 272  4/29/2020             Northwest Territories                 Canada
# ...

# %% [markdown]
# # Q3). In Which Region,Maximum number of Confirmed cases were recored ?

# %%
data.head(2)
# Out:
#          Date State      Region  Confirmed  Deaths  Recovered
# 18  4/29/2020   NaN      Bhutan          7       0          5
# 98  4/29/2020   NaN  MS Zaandam          9       2          0

# %%
data.groupby('Region').Confirmed.sum()
# Out:
# Region
# Bhutan                   7
# Canada                   5
# France                   7
# MS Zaandam               9
# Mainland China           1
# Mauritania               8
# Netherlands              5
# Papua New Guinea         8
# Sao Tome and Principe    8
# UK                       9
# US                       0
# Western Sahara           6
# Yemen                    6
# Name: Confirmed, dtype: int64

# %%
data.groupby('Region').Confirmed.sum().sort_values(ascending=False)
# Out:
# Region
# MS Zaandam               9
# UK                       9
# Mauritania               8
# Papua New Guinea         8
# Sao Tome and Principe    8
# Bhutan                   7
# France                   7
# Western Sahara           6
# Yemen                    6
# Canada                   5
# Netherlands              5
# Mainland China           1
# US                       0
# Name: Confirmed, dtype: int64

# %% [markdown]
# # Q 4). In Which Region,minimum number of Deaths cases were recored ?

# %%
 data.groupby('Region').Confirmed.sum().sort_values(ascending=False).head(20)
# Out:
# Region
# MS Zaandam               9
# UK                       9
# Mauritania               8
# Papua New Guinea         8
# Sao Tome and Principe    8
# Bhutan                   7
# France                   7
# Western Sahara           6
# Yemen                    6
# Canada                   5
# Netherlands              5
# Mainland China           1
# US                       0
# Name: Confirmed, dtype: int64

# %%
 data.head(2)
# Out:
#          Date State      Region  Confirmed  Deaths  Recovered
# 18  4/29/2020   NaN      Bhutan          7       0          5
# 98  4/29/2020   NaN  MS Zaandam          9       2          0

# %%
data.groupby('Region').Deaths.sum()
# Out:
# Region
# Bhutan                   0
# Canada                   1
# France                   0
# MS Zaandam               2
# Mainland China           0
# Mauritania               1
# Netherlands              0
# Papua New Guinea         0
# Sao Tome and Principe    0
# UK                       1
# US                       0
# Western Sahara           0
# Yemen                    0
# Name: Deaths, dtype: int64

# %%
data.groupby('Region').Deaths.sum().sort_values(ascending = True).head(50)
# Out:
# Region
# Bhutan                   0
# France                   0
# Mainland China           0
# Netherlands              0
# Papua New Guinea         0
# Sao Tome and Principe    0
# US                       0
# Western Sahara           0
# Yemen                    0
# Canada                   1
# Mauritania               1
# UK                       1
# MS Zaandam               2
# Name: Deaths, dtype: int64

# %% [markdown]
# # Q5).How many Confirmed, Deaths & Recovered cases were reported from India till 29 April 2020 ?

# %%
data.head(2)
# Out:
#          Date State      Region  Confirmed  Deaths  Recovered
# 18  4/29/2020   NaN      Bhutan          7       0          5
# 98  4/29/2020   NaN  MS Zaandam          9       2          0

# %%
data[data.Region == 'India']
# Out:
# Empty DataFrame
# Columns: [Date, State, Region, Confirmed, Deaths, Recovered]
# Index: []

# %%
data[data.Region == 'Yemen']
# Out:
#           Date State Region  Confirmed  Deaths  Recovered
# 178  4/29/2020   NaN  Yemen          6       0          1

# %%
data[data.Region == 'US']
# Out:
#           Date      State Region  Confirmed  Deaths  Recovered
# 285  4/29/2020  Recovered     US          0       0     120720

# %% [markdown]
# # Q6- A) Sort the entire data wrt No. Of Confirmed cases in ascending order.

# %%
data.head(2)
# Out:
#          Date State      Region  Confirmed  Deaths  Recovered
# 18  4/29/2020   NaN      Bhutan          7       0          5
# 98  4/29/2020   NaN  MS Zaandam          9       2          0

# %%
data.sort_values(by = ['Confirmed'], ascending=True)
# Out:
#           Date                             State                 Region  \
# 285  4/29/2020                         Recovered                     US
# 284  4/29/2020                         Recovered                 Canada
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 305  4/29/2020                             Tibet         Mainland China
# 289  4/29/2020         Saint Pierre and Miquelon                 France
# 184  4/29/2020                          Anguilla                     UK
# 272  4/29/2020             Northwest Territories                 Canada
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 177  4/29/2020                               NaN         Western Sahara
# 194  4/29/2020            British Virgin Islands                     UK
# 288  4/29/2020                  Saint Barthelemy                 France
# 178  4/29/2020                               NaN                  Yemen
# ...

# %%
data.sort_values(by = ['Confirmed'], ascending=True).head(50)
# Out:
#           Date                             State                 Region  \
# 285  4/29/2020                         Recovered                     US
# 284  4/29/2020                         Recovered                 Canada
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 305  4/29/2020                             Tibet         Mainland China
# 289  4/29/2020         Saint Pierre and Miquelon                 France
# 184  4/29/2020                          Anguilla                     UK
# 272  4/29/2020             Northwest Territories                 Canada
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 177  4/29/2020                               NaN         Western Sahara
# 194  4/29/2020            British Virgin Islands                     UK
# 288  4/29/2020                  Saint Barthelemy                 France
# 178  4/29/2020                               NaN                  Yemen
# ...

# %% [markdown]
# # Q. 6 -B) Sort the entire data wrt No. of Recovered cases in Descending Order.

# %%
data.sort_values(by = ['Recovered'], ascending=False)
# Out:
#           Date                             State                 Region  \
# 285  4/29/2020                         Recovered                     US
# 284  4/29/2020                         Recovered                 Canada
# 105  4/29/2020                               NaN             Mauritania
# 288  4/29/2020                  Saint Barthelemy                 France
# 18   4/29/2020                               NaN                 Bhutan
# 177  4/29/2020                               NaN         Western Sahara
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 194  4/29/2020            British Virgin Islands                     UK
# 184  4/29/2020                          Anguilla                     UK
# 305  4/29/2020                             Tibet         Mainland China
# 178  4/29/2020                               NaN                  Yemen
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# ...

# %%
data.sort_values(by = ['Recovered'], ascending=False).head(50)
# Out:
#           Date                             State                 Region  \
# 285  4/29/2020                         Recovered                     US
# 284  4/29/2020                         Recovered                 Canada
# 105  4/29/2020                               NaN             Mauritania
# 288  4/29/2020                  Saint Barthelemy                 France
# 18   4/29/2020                               NaN                 Bhutan
# 177  4/29/2020                               NaN         Western Sahara
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 194  4/29/2020            British Virgin Islands                     UK
# 184  4/29/2020                          Anguilla                     UK
# 305  4/29/2020                             Tibet         Mainland China
# 178  4/29/2020                               NaN                  Yemen
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# ...

# %%
data.to_csv('project5.csv')

# %% [markdown]
# # Covid-19 Data Analysis Project is Completed.

# %% [markdown]
# # Thank you.
