# %% [markdown]
# # Working on Real Proect with Python on 'London Housing Dataset'

# %% [markdown]
# # (A Part of Big Data Analysis)

# %% [markdown]
# # LONDON HOUSING DATASET

# %% [markdown]
# This dataset is primarily centered around the housing market of LONDON. It contains a lot of addition relevant data
#
# Monthly Average house prices
#
# year number of houses sold
#
# Monthly number of crimes committed
#
#
# The data used here id from year 1995 to 2019 of each different area.
#
# This data is avaiable as a CSV file. downloaded from Kaggle.
#
#
# We will analyze this data using this Pandas Dataframe.
#
# Here, random sets of questions are given for which we have to find correct result.
#
# This Project is for beginners and for those who want to know how we analyze big data with python.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('5. London Housing Data.csv')

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
data.count()
# Out:
# date             13549
# area             13549
# average_price    13549
# code             13549
# houses_sold      13455
# no_of_crimes      7439
# dtype: int64

# %%
data.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# dtype: int64

# %%
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# # (A) Convert the Datatype of 'Date' column to Date-Time format.

# %%
data.head()
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
# 2  3/1/1995  city of london          79121  E09000001         14.0
# 3  4/1/1995  city of london          77101  E09000001          7.0
# 4  5/1/1995  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
data.date = pd.to_datetime(data.date)

# %%
data.dtypes
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes            float64
# dtype: object

# %% [markdown]
# # (B-1) Add a new column 'Year' in the dataframe, which contains years only.

# %%
data.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
data['year'] = data.date.dt.year

# %%
data.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes  year
# 0           NaN  1995
# 1           NaN  1995
# 2           NaN  1995
# 3           NaN  1995
# 4           NaN  1995

# %% [markdown]
# # (B-2) Add a new column 'month' as 2nd column in the dataframe,which contains month only.

# %%
data.insert(1, 'month' , data.date.dt.month )

# %%
data.head()
# Out:
#         date  month            area  average_price       code  houses_sold  \
# 0 1995-01-01      1  city of london          91449  E09000001         17.0
# 1 1995-02-01      2  city of london          82203  E09000001          7.0
# 2 1995-03-01      3  city of london          79121  E09000001         14.0
# 3 1995-04-01      4  city of london          77101  E09000001          7.0
# 4 1995-05-01      5  city of london          84409  E09000001         10.0
#
#    no_of_crimes  year
# 0           NaN  1995
# 1           NaN  1995
# 2           NaN  1995
# 3           NaN  1995
# 4           NaN  1995

# %% [markdown]
# # (C) Remove the columns 'Year' and 'month' from the dataframe.

# %%
data.drop(['month' , 'year'], axis=1 , inplace = True )

# %%
data.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %% [markdown]
# # (D) Show all the records where 'No. of Crimes' is 0. And,how many such records are there ?

# %%
data.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
len(data[data.no_of_crimes == 0])
# Out:
# 104

# %% [markdown]
# # (E) What is th maximum & minimum ' average_price' per year in england?

# %%
data['year'] = data.date.dt.year

# %%
data.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes  year
# 0           NaN  1995
# 1           NaN  1995
# 2           NaN  1995
# 3           NaN  1995
# 4           NaN  1995

# %%
df1 = data[data.area == 'england']

# %%
df1
# Out:
#             date     area  average_price       code  houses_sold  \
# 13248 1995-01-01  england          53203  E92000001      47639.0
# 13249 1995-02-01  england          53096  E92000001      47880.0
# 13250 1995-03-01  england          53201  E92000001      67025.0
# 13251 1995-04-01  england          53591  E92000001      56925.0
# 13252 1995-05-01  england          53678  E92000001      64192.0
# ...          ...      ...            ...        ...          ...
# 13544 2019-09-01  england         249942  E92000001      64605.0
# 13545 2019-10-01  england         249376  E92000001      68677.0
# 13546 2019-11-01  england         248515  E92000001      67814.0
# 13547 2019-12-01  england         250410  E92000001          NaN
# 13548 2020-01-01  england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 13248           NaN  1995
# 13249           NaN  1995
# 13250           NaN  1995
# 13251           NaN  1995
# 13252           NaN  1995
# ...

# %%
data.groupby('year').average_price.max()
# Out:
# year
# 1995     200722
# 1996     223197
# 1997     265112
# 1998     277600
# 1999     354241
# 2000     397353
# 2001     451028
# 2002     497538
# 2003     488704
# 2004     559286
# 2005     555847
# 2006     644541
# 2007     830950
# 2008     832753
# 2009     782459
# 2010     884674
# 2011     959520
# 2012    1077366
# 2013    1217729
# 2014    1365050
# 2015    1353679
# 2016    1357231
# 2017    1412255
# 2018    1463378
# 2019    1294113
# 2020    1178166
# Name: average_price, dtype: int64

# %%
data.groupby('year').average_price.min()
# Out:
# year
# 1995     41688
# 1996     40722
# 1997     42353
# 1998     43510
# 1999     43969
# 2000     47604
# 2001     49045
# 2002     54746
# 2003     67520
# 2004     88520
# 2005    110454
# 2006    121124
# 2007    131175
# 2008    120275
# 2009    117079
# 2010    119688
# 2011    115328
# 2012    113011
# 2013    112008
# 2014    114531
# 2015    117156
# 2016    121085
# 2017    121858
# 2018    124038
# 2019    124567
# 2020    126592
# Name: average_price, dtype: int64

# %%
df1.groupby('year').average_price.mean()
# Out:
# year
# 1995     53322.416667
# 1996     54151.500000
# 1997     59160.666667
# 1998     64301.666667
# 1999     70070.750000
# 2000     80814.333333
# 2001     90306.750000
# 2002    107981.500000
# 2003    130218.583333
# 2004    152314.416667
# 2005    163570.000000
# 2006    174351.500000
# 2007    190025.583333
# 2008    182379.916667
# 2009    166558.666667
# 2010    177472.666667
# 2011    175230.000000
# 2012    177488.000000
# 2013    182581.416667
# 2014    197771.083333
# 2015    211174.750000
# 2016    227337.166667
# 2017    238161.166667
# 2018    245018.333333
# 2019    247101.083333
# 2020    247355.000000
# Name: average_price, dtype: float64

# %% [markdown]
# # (F) What is the Maximum & Minimum no. of Crimes recorded per area ?

# %%
data.groupby('area').no_of_crimes.max()
# Out:
# area
# barking and dagenham      2049.0
# barnet                    2893.0
# bexley                    1914.0
# brent                     2937.0
# bromley                   2637.0
# camden                    4558.0
# city of london              10.0
# croydon                   3263.0
# ealing                    3401.0
# east midlands                NaN
# east of england              NaN
# enfield                   2798.0
# england                      NaN
# greenwich                 2853.0
# hackney                   3466.0
# hammersmith and fulham    2645.0
# haringey                  3199.0
# harrow                    1763.0
# havering                  1956.0
# hillingdon                2819.0
# hounslow                  2817.0
# inner london                 NaN
# islington                 3384.0
# kensington and chelsea    2778.0
# kingston upon thames      1379.0
# lambeth                   4701.0
# lewisham                  2813.0
# london                       NaN
# ...

# %%
data.groupby('area').no_of_crimes.min()
# Out:
# area
# barking and dagenham      1217.0
# barnet                    1703.0
# bexley                     860.0
# brent                     1850.0
# bromley                   1441.0
# camden                    2079.0
# city of london               0.0
# croydon                   2031.0
# ealing                    1871.0
# east midlands                NaN
# east of england              NaN
# enfield                   1635.0
# england                      NaN
# greenwich                 1513.0
# hackney                   1870.0
# hammersmith and fulham    1323.0
# haringey                  1536.0
# harrow                     937.0
# havering                  1130.0
# hillingdon                1445.0
# hounslow                  1529.0
# inner london                 NaN
# islington                 1871.0
# kensington and chelsea    1347.0
# kingston upon thames       692.0
# lambeth                   2381.0
# lewisham                  1675.0
# london                       NaN
# ...

# %%
data.groupby('year').no_of_crimes.min().sort_values(ascending=False)
# Out:
# year
# 2020    1124.0
# 2019     974.0
# 2018     898.0
# 2017     868.0
# 2016     795.0
# 2011     790.0
# 2012     774.0
# 2015     763.0
# 2013     740.0
# 2014     692.0
# 2007       0.0
# 2008       0.0
# 2009       0.0
# 2010       0.0
# 2002       0.0
# 2006       0.0
# 2005       0.0
# 2004       0.0
# 2003       0.0
# 2001       0.0
# 1995       NaN
# 1996       NaN
# 1997       NaN
# 1998       NaN
# 1999       NaN
# 2000       NaN
# Name: no_of_crimes, dtype: float64

# %% [markdown]
# # (G) Show the total count of records of each area, where average price is less than 100000.

# %%
data[data.average_price < 100000]
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13330 2001-11-01         england          95083  E92000001     109149.0
# 13331 2001-12-01         england          95992  E92000001      93329.0
# 13332 2002-01-01         england          96215  E92000001      71678.0
# 13333 2002-02-01         england          96676  E92000001      77131.0
# 13334 2002-03-01         england          98962  E92000001     102828.0
#
#        no_of_crimes  year
# 0               NaN  1995
# 1               NaN  1995
# ...

# %%
data[data.average_price < 100000].area.value_counts()
# Out:
# north east              112
# north west              111
# yorks and the humber    110
# east midlands            96
# west midlands            94
# england                  87
# barking and dagenham     85
# south west               78
# east of england          76
# newham                   72
# bexley                   64
# waltham forest           64
# lewisham                 62
# havering                 60
# south east               59
# greenwich                59
# croydon                  57
# enfield                  54
# sutton                   54
# hackney                  53
# redbridge                52
# southwark                48
# tower hamlets            47
# outer london             46
# hillingdon               44
# lambeth                  41
# hounslow                 41
# brent                    40
# london                   39
# merton                   35
# haringey                 33
# bromley                  33
# inner london             31
# ...

# %%
data.to_csv('project8.csv')

# %% [markdown]
# # London Data Analysis Project is Complete.

# %% [markdown]
# # Thank You
